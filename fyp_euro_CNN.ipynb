# %%
# Libraries
import os
import pandas as pd
from PIL import Image, ImageEnhance
import cv2
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from scikeras.wrappers import KerasClassifier
from sklearn.metrics import classification_report, accuracy_score

# %% [markdown]
# Preprocessing

# %%
class CFG:  
    # path defination
    class Path:
        train_df = 'EuroSAT/train.csv'
        val_df = 'EuroSAT/validation.csv'
        test_df = 'EuroSAT/test.csv'
        image_folder = 'EuroSAT'
        model_save_path = 'working/weights/'
        tensorboard_logs_path = "working/tensorboard/logs/"
        figure_save_path = "working/Figures/"
        
    # dataset parameter
    class Dataset:
        batch_size = 64
        img_size = (64, 64)
        buffer_size = 1000
    
    class HyperParameter:
        batch_size = 64
        learning_rate = 0.0001
        input_shape = (64, 64, 3)
        num_classes = 10
        epochs = 100

# %%
class EuroSatLoader:
    def __init__(self, csv_path, image_folder, batch_size = 32, img_size = (32, 32), buffer_size = 100, shuffle = True):
        self.csv_path = csv_path
        self.image_folder = image_folder
        self.batch_size = batch_size
        self.img_size = img_size
        self.shuffle = shuffle
        self.buffer_size = buffer_size
        
        # Load the CSV files using pandas
        self.df = pd.read_csv(self.csv_path)
        # Create a list of image paths and labels for train, validation, and test datasets
        self.image_paths = [os.path.join(self.image_folder, filename) for filename in self.df.Filename] 
        self.labels = self.df.Label.values
        
    def load_image(self, image_path, label):
        image = tf.io.read_file(image_path)
        image = tf.image.decode_jpeg(image, channels=3) #
        image = tf.image.resize(image, self.img_size)
        image = tf.cast(image, tf.float32) / 255.0
        return image, label
    
    def get_dataset(self):
        dataset = tf.data.Dataset.from_tensor_slices((self.image_paths, self.labels))
        dataset = dataset.map(self.load_image, num_parallel_calls=tf.data.AUTOTUNE)
        if self.shuffle:
            dataset = dataset.shuffle(buffer_size=self.buffer_size, reshuffle_each_iteration=True)
        dataset = dataset.batch(batch_size=self.batch_size)
        dataset = dataset.prefetch(tf.data.AUTOTUNE)
        return dataset

# %% [markdown]
# Base Model Creation

# %%
class BaselineCNN:
    def __init__(self, input_shape, num_classes):
        self.input_shape = input_shape
        self.num_classes = num_classes
        self.model = self.build_model()
    
    def build_model(self):
        inputs = tf.keras.layers.Input(shape=self.input_shape)
        x = tf.keras.layers.Conv2D(32, (3,3), activation='relu',padding='same')(inputs)
        x = tf.keras.layers.MaxPooling2D((2,2))(x)
        x = tf.keras.layers.Conv2D(64, (3,3), activation='relu',padding='same')(x)
        x = tf.keras.layers.MaxPooling2D((2,2))(x)
        x = tf.keras.layers.Conv2D(128, (3,3), activation='relu',padding='same')(x)
        x = tf.keras.layers.MaxPooling2D((2,2))(x)
        x = tf.keras.layers.Dropout(0.3) (x)
        x = tf.keras.layers.Conv2D(128, (3,3), activation='relu',padding='same')(x)
        x = tf.keras.layers.MaxPooling2D((2,2))(x)
        x = tf.keras.layers.Dropout(0.3) (x)
        x = tf.keras.layers.Conv2D(64, (3,3), activation='relu',padding='same')(x)
        x = tf.keras.layers.MaxPooling2D((2,2))(x)
        x = tf.keras.layers.Conv2D(32, (3,3), activation='relu',padding='same')(x)
        x = tf.keras.layers.MaxPooling2D((2,2))(x)
        x = tf.keras.layers.GlobalAveragePooling2D()(x)
        x = tf.keras.layers.Dense(64, activation='relu')(x)
        outputs = tf.keras.layers.Dense(self.num_classes, activation='softmax')(x)
        model = tf.keras.models.Model(inputs=inputs, outputs=outputs)
        return model
    
    def compile(self, learning_rate):
        self.model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate =learning_rate), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

    def train(self, train_data, val_data, epochs, batch_size, model_save_path, log_dir):
        early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, verbose=1, mode='min', restore_best_weights=True)
        checkpoint = tf.keras.callbacks.ModelCheckpoint(model_save_path + 'best_model.weights.h5', monitor='val_loss', mode='min', save_weights_only=True,save_best_only=True, verbose=1)
        tensorboard = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1, write_graph=True, write_images=True)
        callbacks = [early_stop, checkpoint, tensorboard]
        history = self.model.fit(train_data, 
                                 epochs=epochs,
                                 batch_size=batch_size, 
                                 validation_data=val_data, 
                                 callbacks=callbacks)
        return history
    def evaluate(self, data):
        loss, accuracy = self.model.evaluate(data)
        return loss, accuracy
    
    def predict(self, data):
        return self.model.predict(data)
    
    def summary(self):
        return self.model.summary()
        
    def load_model(self, model_path):
        self.model.load_weights(model_path)
        
    def plot_model_architecture(self, file_path):
        tf.keras.utilsplot_model(self, to_file=file_path, show_shapes=True)

# %% [markdown]
# Model Creation

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import roc_auc_score

class ModelUtils:
    
    @staticmethod
    def plot_cm(y_true, y_pred, class_names,save_path, figsize=(10,10)):
        cm = confusion_matrix(y_true, y_pred, labels=np.unique(y_true))
        cm_sum = np.sum(cm, axis=1, keepdims=True)
        cm_perc = cm / cm_sum.astype(float) * 100
        annot = np.empty_like(cm).astype(str)
        nrows, ncols = cm.shape
        for i in range(nrows):
            for j in range(ncols):
                c = cm[i, j]
                p = cm_perc[i, j]
                if i == j:
                    s = cm_sum[i]
                    annot[i, j] = '%.1f%%\n%d/%d' % (p, c, s)
                elif c == 0:
                    annot[i, j] = ''
                else:
                    annot[i, j] = '%.1f%%\n%d' % (p, c)
        # cm = pd.DataFrame(cm, index=np.unique(y_true), columns=np.unique(y_true))
        cm = pd.DataFrame(cm, index=[i for i in class_names],
                    columns = [i for i in class_names])
        
        cm.index.name = 'True label'
        cm.columns.name = 'Predicted label'
        fig, ax = plt.subplots(figsize=figsize)
        sns.heatmap(cm, annot=annot, fmt='', ax=ax)
        plt.savefig(save_path+'confusion_matrix.png')
        
        
    
    @staticmethod
    def plot_confusion_matrix(y_true, y_pred, labels):
        cm = confusion_matrix(y_true, y_pred, labels=labels)
        ax = plt.subplot()
        sns.heatmap(cm, annot=True, ax=ax, cmap='Blues', fmt='g')
        ax.set_xlabel('Predicted labels')
        ax.set_ylabel('True labels')
        ax.set_title('Confusion Matrix')
        ax.xaxis.set_ticklabels(labels)
        ax.yaxis.set_ticklabels(labels)
        plt.show()
        
    

    @staticmethod
    def plot_loss_accuracy(save_path,history):
        fig, ax = plt.subplots(1, 2, figsize=(15, 5))
        ax[0].plot(history.history['loss'], label='train')
        ax[0].plot(history.history['val_loss'], label='validation')
        ax[0].set_xlabel('Epoch')
        ax[0].set_ylabel('Loss')
        ax[0].set_title('Loss vs Epoch')
        ax[0].legend()
        ax[1].plot(history.history['accuracy'], label='train')
        ax[1].plot(history.history['val_accuracy'], label='validation')
        ax[1].set_xlabel('Epoch')
        ax[1].set_ylabel('Accuracy')
        ax[1].set_title('Accuracy vs Epoch')
        ax[1].legend()
        plt.savefig(save_path+'loss_accuracy_curve.png')
        plt.show()

    # function for scoring roc auc score for multi-class
    @staticmethod
    def multiclass_roc_auc_score(y_true, model_predicted_label,class_names,save_path, average="macro"):
        fig, c_ax = plt.subplots(1,1, figsize = (16, 16))
        lb = LabelBinarizer()
        lb.fit(y_true)
        y_test = lb.transform(y_true)
        y_pred = lb.transform(model_predicted_label)
        
        for (idx, c_label) in enumerate(class_names):
            fpr, tpr, thresholds = roc_curve(y_test[:,idx].astype(int), y_pred[:,idx])
            c_ax.plot(fpr, tpr, label = '%s (AUC:%0.2f)'  % (c_label, auc(fpr, tpr)))
        c_ax.plot(fpr, fpr, 'b-', label = 'Random Guessing')
        
        c_ax.legend()
        c_ax.set_xlabel('False Positive Rate')
        c_ax.set_ylabel('True Positive Rate')
        plt.savefig(save_path+'roc_auc_curve.png')
        plt.show()
        return roc_auc_score(y_test, y_pred, average=average)

# %%
from pathlib import Path
import tensorflow as tf
import numpy as np
import json
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report

if __name__ == '__main__':
    cfg = CFG()
    Path(cfg.Path.model_save_path).mkdir(parents = True, exist_ok = True)
    Path(cfg.Path.tensorboard_logs_path).mkdir(parents = True, exist_ok = True)
    Path(cfg.Path.figure_save_path).mkdir(parents = True, exist_ok = True)

    train_loader = EuroSatLoader(csv_path = cfg.Path.train_df, 
                                image_folder = cfg.Path.image_folder,
                                batch_size = cfg.Dataset.batch_size,
                                img_size = cfg.Dataset.img_size,
                                buffer_size = cfg.Dataset.buffer_size, 
                                shuffle = True)
    train_dataset = train_loader.get_dataset()

    # print("Train Dataset")
    # for i, (x, y) in enumerate(train_dataset):
    #     print(x.shape, y.shape)
    #     if i == 10:
    #         break

    val_loader = EuroSatLoader(csv_path = cfg.Path.val_df, 
                                image_folder = cfg.Path.image_folder,
                                batch_size = cfg.Dataset.batch_size,
                                img_size = cfg.Dataset.img_size,
                                buffer_size = cfg.Dataset.buffer_size, 
                                shuffle = False)
    val_dataset = val_loader.get_dataset()
    test_loader = EuroSatLoader(csv_path = cfg.Path.test_df, 
                                image_folder = cfg.Path.image_folder,
                                batch_size = cfg.Dataset.batch_size,
                                img_size = cfg.Dataset.img_size,
                                buffer_size = cfg.Dataset.buffer_size, 
                                shuffle = False)
    test_dataset = test_loader.get_dataset()
    
    model = BaselineCNN(input_shape = cfg.HyperParameter.input_shape, 
                        num_classes = cfg.HyperParameter.num_classes)
    
    print(f"INFO ===========Training Started===============")
    model.compile(learning_rate= cfg.HyperParameter.learning_rate)
    history = model.train(train_data = train_dataset, 
                          val_data = val_dataset,
                          epochs = cfg.HyperParameter.epochs,
                          batch_size= cfg.HyperParameter.batch_size, 
                          model_save_path= cfg.Path.model_save_path,
                          log_dir= cfg.Path.tensorboard_logs_path)
    print(f"INFO ===========Training Finished===============")
    print(f"INFO ===========Plot Curve===============")
    ModelUtils.plot_loss_accuracy(cfg.Path.figure_save_path,history)
# Out:
# INFO ===========Training Started===============
# Epoch 1/100
# 295/296 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.1698 - loss: 2.0955
# Epoch 1: val_loss improved from inf to 1.36656, saving model to working/weights/best_model.weights.h5
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 41s 128ms/step - accuracy: 0.1705 - loss: 2.0936 - val_accuracy: 0.4174 - val_loss: 1.3666
# Epoch 2/100
# 295/296 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.4578 - loss: 1.3085
# Epoch 2: val_loss improved from 1.36656 to 1.17336, saving model to working/weights/best_model.weights.h5
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 25s 82ms/step - accuracy: 0.4580 - loss: 1.3082 - val_accuracy: 0.5661 - val_loss: 1.1734
# Epoch 3/100
# 295/296 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.5688 - loss: 1.1424
# Epoch 3: val_loss improved from 1.17336 to 1.02863, saving model to working/weights/best_model.weights.h5
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 24s 82ms/step - accuracy: 0.5689 - loss: 1.1423 - val_accuracy: 0.6093 - val_loss: 1.0286
# Epoch 4/100
# 295/296 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.6137 - loss: 1.0354
# Epoch 4: val_loss improved from 1.02863 to 0.95555, saving model to working/weights/best_model.weights.h5
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 26s 88ms/step - accuracy: 0.6138 - loss: 1.0352 - val_accuracy: 0.6413 - val_loss: 0.9555
# Epoch 5/100
# 295/296 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.6662 - loss: 0.9199
# Epoch 5: val_loss improved from 0.95555 to 0.83101, saving model to working/weights/best_model.weights.h5
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 26s 88ms/step - accuracy: 0.6663 - loss: 0.9197 - val_accuracy: 0.6931 - val_loss: 0.8310
# Epoch 6/100
# 295/296 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.6904 - loss: 0.8509
# Epoch 6: val_loss improved from 0.83101 to 0.82356, saving model to working/weights/best_model.weights.h5
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 25s 83ms/step - accuracy: 0.6904 - loss: 0.8508 - val_accuracy: 0.6898 - val_loss: 0.8236
# Epoch 7/100
# 295/296 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.7070 - loss: 0.8039
# Epoch 7: val_loss improved from 0.82356 to 0.76613, saving model to working/weights/best_model.weights.h5
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 24s 82ms/step - accuracy: 0.7071 - loss: 0.8038 - val_accuracy: 0.7174 - val_loss: 0.7661
# Epoch 8/100
# 295/296 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.7165 - loss: 0.7754
# Epoch 8: val_loss improved from 0.76613 to 0.73284, saving model to working/weights/best_model.weights.h5
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 25s 84ms/step - accuracy: 0.7165 - loss: 0.7753 - val_accuracy: 0.7252 - val_loss: 0.7328
# Epoch 9/100
# 295/296 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.7259 - loss: 0.7388
# Epoch 9: val_loss improved from 0.73284 to 0.68928, saving model to working/weights/best_model.weights.h5
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 26s 87ms/step - accuracy: 0.7259 - loss: 0.7388 - val_accuracy: 0.7428 - val_loss: 0.6893
# Epoch 10/100
# 295/296 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.7279 - loss: 0.7233
# Epoch 10: val_loss improved from 0.68928 to 0.68207, saving model to working/weights/best_model.weights.h5
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 26s 86ms/step - accuracy: 0.7279 - loss: 0.7232 - val_accuracy: 0.7461 - val_loss: 0.6821
# Epoch 11/100
# 295/296 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.7302 - loss: 0.7232
# Epoch 11: val_loss improved from 0.68207 to 0.66766, saving model to working/weights/best_model.weights.h5
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 25s 83ms/step - accuracy: 0.7302 - loss: 0.7230 - val_accuracy: 0.7507 - val_loss: 0.6677
# Epoch 12/100
# 295/296 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.7447 - loss: 0.6816
# Epoch 12: val_loss improved from 0.66766 to 0.63731, saving model to working/weights/best_model.weights.h5
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 25s 83ms/step - accuracy: 0.7447 - loss: 0.6815 - val_accuracy: 0.7643 - val_loss: 0.6373
# Epoch 13/100
# 295/296 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.7500 - loss: 0.6707
# Epoch 13: val_loss improved from 0.63731 to 0.62145, saving model to working/weights/best_model.weights.h5
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 25s 83ms/step - accuracy: 0.7500 - loss: 0.6706 - val_accuracy: 0.7683 - val_loss: 0.6214
# Epoch 14/100
# 295/296 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.7566 - loss: 0.6501
# Epoch 14: val_loss did not improve from 0.62145
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 25s 84ms/step - accuracy: 0.7567 - loss: 0.6501 - val_accuracy: 0.7637 - val_loss: 0.6341
# Epoch 15/100
# 295/296 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.7640 - loss: 0.6300
# Epoch 15: val_loss did not improve from 0.62145
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 26s 87ms/step - accuracy: 0.7640 - loss: 0.6299 - val_accuracy: 0.7604 - val_loss: 0.6403
# Epoch 16/100
# 295/296 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.7646 - loss: 0.6257
# Epoch 16: val_loss did not improve from 0.62145
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 26s 87ms/step - accuracy: 0.7646 - loss: 0.6256 - val_accuracy: 0.7576 - val_loss: 0.6611
# Epoch 17/100
# 295/296 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.7628 - loss: 0.6278
# Epoch 17: val_loss did not improve from 0.62145
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 26s 87ms/step - accuracy: 0.7628 - loss: 0.6277 - val_accuracy: 0.7687 - val_loss: 0.6334
# Epoch 18/100
# 295/296 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.7763 - loss: 0.6048
# Epoch 18: val_loss improved from 0.62145 to 0.57440, saving model to working/weights/best_model.weights.h5
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 26s 88ms/step - accuracy: 0.7764 - loss: 0.6048 - val_accuracy: 0.7854 - val_loss: 0.5744
# Epoch 19/100
# 295/296 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.7838 - loss: 0.5851
# Epoch 19: val_loss improved from 0.57440 to 0.56583, saving model to working/weights/best_model.weights.h5
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 26s 87ms/step - accuracy: 0.7838 - loss: 0.5850 - val_accuracy: 0.7909 - val_loss: 0.5658
# Epoch 20/100
# 295/296 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.7892 - loss: 0.5744
# Epoch 20: val_loss improved from 0.56583 to 0.55622, saving model to working/weights/best_model.weights.h5
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 26s 87ms/step - accuracy: 0.7892 - loss: 0.5744 - val_accuracy: 0.7950 - val_loss: 0.5562
# Epoch 21/100
# 295/296 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.7851 - loss: 0.5792
# Epoch 21: val_loss improved from 0.55622 to 0.51888, saving model to working/weights/best_model.weights.h5
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 26s 86ms/step - accuracy: 0.7851 - loss: 0.5791 - val_accuracy: 0.8096 - val_loss: 0.5189
# Epoch 22/100
# 295/296 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.7920 - loss: 0.5614
# Epoch 22: val_loss did not improve from 0.51888
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 27s 91ms/step - accuracy: 0.7920 - loss: 0.5613 - val_accuracy: 0.8128 - val_loss: 0.5220
# Epoch 23/100
# 295/296 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.7905 - loss: 0.5647
# Epoch 23: val_loss did not improve from 0.51888
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 25s 84ms/step - accuracy: 0.7906 - loss: 0.5646 - val_accuracy: 0.8050 - val_loss: 0.5278
# Epoch 24/100
# 295/296 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.7986 - loss: 0.5478
# Epoch 24: val_loss did not improve from 0.51888
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 25s 84ms/step - accuracy: 0.7987 - loss: 0.5478 - val_accuracy: 0.8059 - val_loss: 0.5457
# Epoch 25/100
# 295/296 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.
100
# 295/296 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.8874 - loss: 0.3284
# Epoch 60: val_loss did not improve from 0.32851
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 26s 86ms/step - accuracy: 0.8874 - loss: 0.3284 - val_accuracy: 0.8793 - val_loss: 0.3400
# Epoch 61/100
# 295/296 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.8862 - loss: 0.3212
# Epoch 61: val_loss improved from 0.32851 to 0.32070, saving model to working/weights/best_model.weights.h5
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 26s 86ms/step - accuracy: 0.8862 - loss: 0.3212 - val_accuracy: 0.8870 - val_loss: 0.3207
# Epoch 62/100
# 295/296 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.8879 - loss: 0.3149
# Epoch 62: val_loss did not improve from 0.32070
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 26s 87ms/step - accuracy: 0.8880 - loss: 0.3149 - val_accuracy: 0.8687 - val_loss: 0.3743
# Epoch 63/100
# 295/296 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.8881 - loss: 0.3154
# Epoch 63: val_loss did not improve from 0.32070
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 26s 87ms/step - accuracy: 0.8881 - loss: 0.3153 - val_accuracy: 0.8865 - val_loss: 0.3227
# Epoch 64/100
# 295/296 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.8910 - loss: 0.3056
# Epoch 64: val_loss did not improve from 0.32070
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 26s 87ms/step - accuracy: 0.8910 - loss: 0.3056 - val_accuracy: 0.8826 - val_loss: 0.3383
# Epoch 65/100
# 295/296 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.8899 - loss: 0.3041
# Epoch 65: val_loss did not improve from 0.32070
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 26s 86ms/step - accuracy: 0.8900 - loss: 0.3040 - val_accuracy: 0.8611 - val_loss: 0.3847
# Epoch 66/100
# 295/296 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.8901 - loss: 0.3025
# Epoch 66: val_loss improved from 0.32070 to 0.29002, saving model to working/weights/best_model.weights.h5
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 26s 87ms/step - accuracy: 0.8901 - loss: 0.3024 - val_accuracy: 0.8998 - val_loss: 0.2900
# Epoch 67/100
# 295/296 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.8946 - loss: 0.2932
# Epoch 67: val_loss did not improve from 0.29002
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 27s 90ms/step - accuracy: 0.8946 - loss: 0.2932 - val_accuracy: 0.8870 - val_loss: 0.3259
# Epoch 68/100
# 295/296 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.8957 - loss: 0.2968
# Epoch 68: val_loss did not improve from 0.29002
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 26s 88ms/step - accuracy: 0.8957 - loss: 0.2968 - val_accuracy: 0.8765 - val_loss: 0.3467
# Epoch 69/100
# 295/296 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.8994 - loss: 0.2809
# Epoch 69: val_loss did not improve from 0.29002
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 26s 88ms/step - accuracy: 0.8994 - loss: 0.2809 - val_accuracy: 0.8991 - val_loss: 0.2908
# Epoch 70/100
# 295/296 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.9003 - loss: 0.2793
# Epoch 70: val_loss did not improve from 0.29002
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 26s 88ms/step - accuracy: 0.9003 - loss: 0.2793 - val_accuracy: 0.8985 - val_loss: 0.2910
# Epoch 71/100
# 295/296 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.8940 - loss: 0.2870
# Epoch 71: val_loss improved from 0.29002 to 0.27931, saving model to working/weights/best_model.weights.h5
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 26s 89ms/step - accuracy: 0.8940 - loss: 0.2869 - val_accuracy: 0.9043 - val_loss: 0.2793
# Epoch 72/100
# 295/296 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9042 - loss: 0.2690
# Epoch 72: val_loss did not improve from 0.27931
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 27s 89ms/step - accuracy: 0.9042 - loss: 0.2690 - val_accuracy: 0.8998 - val_loss: 0.2873
# Epoch 73/100
# 295/296 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9051 - loss: 0.2693
# Epoch 73: val_loss did not improve from 0.27931
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 27s 90ms/step - accuracy: 0.9051 - loss: 0.2692 - val_accuracy: 0.8911 - val_loss: 0.3168
# Epoch 74/100
# 295/296 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.9074 - loss: 0.2647
# Epoch 74: val_loss did not improve from 0.27931
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 26s 89ms/step - accuracy: 0.9074 - loss: 0.2646 - val_accuracy: 0.8848 - val_loss: 0.3313
# Epoch 75/100
# 295/296 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.9066 - loss: 0.2598
# Epoch 75: val_loss did not improve from 0.27931
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 27s 90ms/step - accuracy: 0.9066 - loss: 0.2597 - val_accuracy: 0.8978 - val_loss: 0.2865
# Epoch 76/100
# 295/296 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.9115 - loss: 0.2514
# Epoch 76: val_loss improved from 0.27931 to 0.26663, saving model to working/weights/best_model.weights.h5
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 27s 92ms/step - accuracy: 0.9115 - loss: 0.2514 - val_accuracy: 0.9072 - val_loss: 0.2666
# Epoch 77/100
# 295/296 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9158 - loss: 0.2432
# Epoch 77: val_loss did not improve from 0.26663
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 27s 90ms/step - accuracy: 0.9158 - loss: 0.2432 - val_accuracy: 0.8900 - val_loss: 0.3013
# Epoch 78/100
# 295/296 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.9147 - loss: 0.2427
# Epoch 78: val_loss did not improve from 0.26663
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 27s 91ms/step - accuracy: 0.9147 - loss: 0.2427 - val_accuracy: 0.8952 - val_loss: 0.2991
# Epoch 79/100
# 295/296 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9116 - loss: 0.2533
# Epoch 79: val_loss did not improve from 0.26663
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 27s 90ms/step - accuracy: 0.9116 - loss: 0.2532 - val_accuracy: 0.8935 - val_loss: 0.3084
# Epoch 80/100
# 295/296 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9135 - loss: 0.2477
# Epoch 80: val_loss improved from 0.26663 to 0.24771, saving model to working/weights/best_model.weights.h5
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 27s 91ms/step - accuracy: 0.9135 - loss: 0.2476 - val_accuracy: 0.9128 - val_loss: 0.2477
# Epoch 81/100
# 295/296 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.9134 - loss: 0.2337
# Epoch 81: val_loss did not improve from 0.24771
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 29s 97ms/step - accuracy: 0.9134 - loss: 0.2337 - val_accuracy: 0.9037 - val_loss: 0.2777
# Epoch 82/100
# 295/296 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.9208 - loss: 0.2252
# Epoch 82: val_loss did not improve from 0.24771
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 27s 89ms/step - accuracy: 0.9207 - loss: 0.2251 - val_accuracy: 0.8991 - val_loss: 0.2927
# Epoch 83/100
# 295/296 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.9196 - loss: 0.2280
# Epoch 83: val_loss did not improve from 0.24771
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 26s 88ms/step - accuracy: 0.9197 - loss: 0.2280 - val_accuracy: 0.9089 - val_loss: 0.2538
# Epoch 84/100
# 295/296 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.9228 - loss: 0.2253
# Epoch 84: val_loss did not improve from 0.24771
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 26s 86ms/step - accuracy: 0.9228 - loss: 0.2253 - val_accuracy: 0.9133 - val_loss: 0.2509
# Epoch 85/100
# 295/296 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.9154 - loss: 0.2371
# Epoch 85: val_loss did not improve from 0.24771
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 26s 88ms/step - accuracy: 0.9154 - loss: 0.2370 - val_accuracy: 0.9115 - val_loss: 0.2562
# Epoch 85: early stopping
# Restoring model weights from the end of the best epoch: 80.
# INFO ===========Training Finished===============
# INFO ===========Plot Curve===============

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import auc
model.load_model('working/weights/best_model.weights.h5')

train_loss, train_acc = model.evaluate(train_dataset)
print(f"train_loss:{train_loss}:: train_accuracy: {train_acc}")

val_loss, val_acc = model.evaluate(val_dataset)
print(f"val_loss:{val_loss}:: val_acc: {val_acc}")

test_loss, test_acc = model.evaluate(test_dataset)
print(f"test_loss:{test_loss}:: test_acc: {test_acc}")
    
predictions = model.predict(test_dataset)
predicted_label = np.argmax(predictions, axis = 1)

class_names = ["AnnualCrop","Forest","HerbaceousVegetation","Highway","Industrial",
                "Pasture","PermanentCrop","Residential","River","SeaLake"]

true_labels = []
for image, label in test_dataset: #.as_numpy_iterator()
    true_labels += list(label.numpy())

# Plot confusion Matrix
ModelUtils.plot_cm(y_true = true_labels, y_pred = predicted_label, class_names = class_names,save_path=cfg.Path.figure_save_path)
#Plot Roc Auc Curve
ModelUtils.multiclass_roc_auc_score(y_true= true_labels, model_predicted_label= predicted_label,class_names = class_names,save_path=cfg.Path.figure_save_path)
# Out:
# 296/296 ━━━━━━━━━━━━━━━━━━━━ 8s 28ms/step - accuracy: 0.9335 - loss: 0.1946
# train_loss:0.18919317424297333:: train_accuracy: 0.9358201026916504
# 85/85 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - accuracy: 0.9142 - loss: 0.2434
# val_loss:0.2477082461118698:: val_acc: 0.9127777814865112
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - accuracy: 0.9152 - loss: 0.2483
# test_loss:0.24643179774284363:: test_acc: 0.9174073934555054
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step
# C:\Users\User\AppData\Local\Temp\ipykernel_23756\1565407622.py:21: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   annot[i, j] = '%.1f%%\n%d/%d' % (p, c, s)
# 0.9517809013605442
