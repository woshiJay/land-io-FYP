# %% [markdown]
# Xception

# %%
# Libraries
import os
from PIL import Image, ImageEnhance
import cv2
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import Xception
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, GlobalAveragePooling2D, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

# %%
def preprocess_image(image_path, size=(224, 224)):
    img = Image.open(image_path)
    
    # Quality enhancement
    enhancer = ImageEnhance.Sharpness(img)
    img = enhancer.enhance(2.0)  # Increase sharpness
    
    # Noise reduction
    image = cv2.cvtColor(np.array(img), cv2.COLOR_RGB2BGR)
    image = cv2.GaussianBlur(image, (5, 5), 0)
    img = Image.fromarray(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    
    # Consistency
    img = img.resize(size, Image.LANCZOS)
    
    # Normalization
    img_array = np.array(img) / 255.0
    
    # Convert back to image
    img = Image.fromarray((img_array * 255).astype(np.uint8))
    
    return img

# Apply preprocessing and save to new directory
input_dir = 'data/images_train_test_val/train'
output_dir = 'data/processed_images'

if not os.path.exists(output_dir):
    os.makedirs(output_dir)

for category in os.listdir(input_dir):
    category_path = os.path.join(input_dir, category)
    if os.path.isdir(category_path):
        output_category_path = os.path.join(output_dir, category)
        if not os.path.exists(output_category_path):
            os.makedirs(output_category_path)
        for image_name in os.listdir(category_path):
            image_path = os.path.join(category_path, image_name)
            preprocessed_img = preprocess_image(image_path)
            preprocessed_img.save(os.path.join(output_category_path, image_name))

# %% [markdown]
# Check for Image Corruption

# %%
from PIL import UnidentifiedImageError

def check_images(directory):
    corrupted_images = []
    for root, _, files in os.walk(directory):
        for file in files:
            file_path = os.path.join(root, file)
            try:
                img = Image.open(file_path)
                img.verify()  # This will raise an exception if the image is corrupted
            except (UnidentifiedImageError, IOError) as e:
                corrupted_images.append(file_path)
                print(f"Corrupted image: {file_path} - {e}")
    return corrupted_images

corrupted_images = check_images('images')
print(f"Total corrupted images: {len(corrupted_images)}")
# Out:
# Total corrupted images: 0

# %%
train_dir = 'data/processed_images'
val_dir = 'data/images_train_test_val/validation'
test_dir = 'data/images_train_test_val/test'

datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
)

train_generator = datagen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=64,
    class_mode='categorical'
)

val_generator = datagen.flow_from_directory(
    val_dir,
    target_size=(224, 224),
    batch_size=64,
    class_mode='categorical'
)

test_generator = datagen.flow_from_directory(
    test_dir,
    target_size=(224, 224),
    batch_size=64,
    class_mode='categorical'
)
# Out:
# Found 7350 images belonging to 21 classes.
# Found 2100 images belonging to 21 classes.
# Found 1050 images belonging to 21 classes.

# %%
def create_xception_model(input_shape=(224, 224, 3), num_classes=21, l2_rate=0.01):
    # Create the base pre-trained model
    base_model = Xception(weights='imagenet', include_top=False, input_shape=input_shape)
    
    # Add custom layers
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(512, activation='relu', kernel_regularizer=l2(0.01))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    x = Dense(256, activation='relu', kernel_regularizer=l2(0.01))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)
    predictions = Dense(21, activation='softmax')(x)

    # Construct the full model
    model = Model(inputs=base_model.input, outputs=predictions)

    # Freeze the base model layers
    for layer in base_model.layers:
        layer.trainable = False

    # Compile the model
    model.compile(optimizer=Adam(learning_rate=0.0001),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    return model

# Create the Xception model
model = create_xception_model()
# Out:
# 2024-07-23 01:54:58.420885: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1
# 2024-07-23 01:54:58.420931: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 8.00 GB
# 2024-07-23 01:54:58.420949: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 2.67 GB
# 2024-07-23 01:54:58.421196: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-07-23 01:54:58.421223: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
import json
import os

class SaveHistoryCallback(tf.keras.callbacks.Callback):
    def __init__(self, file_path):
        super(SaveHistoryCallback, self).__init__()
        self.file_path = file_path
        # Create the file initially or clear existing file
        if not os.path.exists(file_path):
            with open(file_path, 'w') as f:
                json.dump({}, f)

    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        with open(self.file_path, 'r+') as f:
            history = json.load(f)
            for key, value in logs.items():
                if key in history:
                    history[key].append(value)
                else:
                    history[key] = [value]
            f.seek(0)  # Go to the beginning of the file
            json.dump(history, f, indent=4)

# %%
# Define callbacks
checkpoint = ModelCheckpoint(
    'models/best_Xception_model.keras', 
    monitor='val_loss', 
    save_best_only=True, 
    mode='min',
    verbose=1
    )

early_stopping = EarlyStopping(
    monitor='val_loss', 
    patience=5, 
    mode='min',
    verbose=1,
    restore_best_weights=True
    )

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

history = model.fit(
    train_generator,
    epochs=20,
    validation_data=val_generator,
    callbacks=[checkpoint, early_stopping, SaveHistoryCallback('models/xception_history.json')]
)
# Out:
# Epoch 1/20
# 2024-07-23 01:55:05.518283: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# /Users/jay/anaconda3/envs/tf_m1_env/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.2916 - loss: 15.5176
# Epoch 1: val_loss improved from inf to 11.19468, saving model to models/best_Xception_model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 325s 3s/step - accuracy: 0.2931 - loss: 15.5047 - val_accuracy: 0.7705 - val_loss: 11.1947
# Epoch 2/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7321 - loss: 10.3948
# Epoch 2: val_loss improved from 11.19468 to 7.91380, saving model to models/best_Xception_model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 280s 2s/step - accuracy: 0.7323 - loss: 10.3876 - val_accuracy: 0.8152 - val_loss: 7.9138
# Epoch 3/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7874 - loss: 7.4355
# Epoch 3: val_loss improved from 7.91380 to 5.75235, saving model to models/best_Xception_model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 278s 2s/step - accuracy: 0.7875 - loss: 7.4307 - val_accuracy: 0.8319 - val_loss: 5.7524
# Epoch 4/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8239 - loss: 5.4328
# Epoch 4: val_loss improved from 5.75235 to 4.30987, saving model to models/best_Xception_model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 275s 2s/step - accuracy: 0.8239 - loss: 5.4297 - val_accuracy: 0.8486 - val_loss: 4.3099
# Epoch 5/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8356 - loss: 4.0893
# Epoch 5: val_loss improved from 4.30987 to 3.30415, saving model to models/best_Xception_model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 274s 2s/step - accuracy: 0.8356 - loss: 4.0872 - val_accuracy: 0.8605 - val_loss: 3.3041
# Epoch 6/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8456 - loss: 3.2007
# Epoch 6: val_loss improved from 3.30415 to 2.65528, saving model to models/best_Xception_model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 279s 2s/step - accuracy: 0.8456 - loss: 3.1992 - val_accuracy: 0.8571 - val_loss: 2.6553
# Epoch 7/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8545 - loss: 2.5847
# Epoch 7: val_loss improved from 2.65528 to 2.20671, saving model to models/best_Xception_model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 279s 2s/step - accuracy: 0.8545 - loss: 2.5837 - val_accuracy: 0.8581 - val_loss: 2.2067
# Epoch 8/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8571 - loss: 2.1573
# Epoch 8: val_loss improved from 2.20671 to 1.89130, saving model to models/best_Xception_model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 278s 2s/step - accuracy: 0.8571 - loss: 2.1567 - val_accuracy: 0.8614 - val_loss: 1.8913
# Epoch 9/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8661 - loss: 1.8800
# Epoch 9: val_loss improved from 1.89130 to 1.67629, saving model to models/best_Xception_model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 283s 2s/step - accuracy: 0.8660 - loss: 1.8795 - val_accuracy: 0.8771 - val_loss: 1.6763
# Epoch 10/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8602 - loss: 1.6949
# Epoch 10: val_loss improved from 1.67629 to 1.54852, saving model to models/best_Xception_model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 279s 2s/step - accuracy: 0.8602 - loss: 1.6946 - val_accuracy: 0.8695 - val_loss: 1.5485
# Epoch 11/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8707 - loss: 1.5544
# Epoch 11: val_loss improved from 1.54852 to 1.44753, saving model to models/best_Xception_model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 281s 2s/step - accuracy: 0.8706 - loss: 1.5542 - val_accuracy: 0.8710 - val_loss: 1.4475
# Epoch 12/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8666 - loss: 1.4625
# Epoch 12: val_loss improved from 1.44753 to 1.37273, saving model to models/best_Xception_model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 285s 2s/step - accuracy: 0.8666 - loss: 1.4624 - val_accuracy: 0.8667 - val_loss: 1.3727
# Epoch 13/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8666 - loss: 1.4005
# Epoch 13: val_loss improved from 1.37273 to 1.32807, saving model to models/best_Xception_model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 297s 3s/step - accuracy: 0.8666 - loss: 1.4004 - val_accuracy: 0.8629 - val_loss: 1.3281
# Epoch 14/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8678 - loss: 1.3610
# Epoch 14: val_loss improved from 1.32807 to 1.28359, saving model to models/best_Xception_model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 285s 2s/step - accuracy: 0.8678 - loss: 1.3609 - val_accuracy: 0.8776 - val_loss: 1.2836
# Epoch 15/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8690 - loss: 1.3261
# Epoch 15: val_loss improved from 1.28359 to 1.25316, saving model to models/best_Xception_model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 288s 2s/step - accuracy: 0.8691 - loss: 1.3260 - val_accuracy: 0.8729 - val_loss: 1.2532
# Epoch 16/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8733 - loss: 1.2845
# Epoch 16: val_loss improved from 1.25316 to 1.24897, saving model to models/best_Xception_model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 293s 3s/step - accuracy: 0.8733 - loss: 1.2845 - val_accuracy: 0.8676 - val_loss: 1.2490
# Epoch 17/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8725 - loss: 1.2680
# Epoch 17: val_loss improved from 1.24897 to 1.23063, saving model to models/best_Xception_model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 288s 2s/step - accuracy: 0.8725 - loss: 1.2679 - val_accuracy: 0.8729 - val_loss: 1.2306
# Epoch 18/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8693 - loss: 1.2593
# Epoch 18: val_loss improved from 1.23063 to 1.21790, saving model to models/best_Xception_model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 290s 3s/step - accuracy: 0.8692 - loss: 1.2593 - val_accuracy: 0.8705 - val_loss: 1.2179
# Epoch 19/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8653 - loss: 1.2610
# Epoch 19: val_loss improved from 1.21790 to 1.20669, saving model to models/best_Xception_model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 291s 3s/step - accuracy: 0.8653 - loss: 1.2610 - val_accuracy: 0.8652 - val_loss: 1.2067
# Epoch 20/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8784 - loss: 1.2362
# Epoch 20: val_loss improved from 1.20669 to 1.19453, saving model to models/best_Xception_model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 287s 2s/step - accuracy: 0.8784 - loss: 1.2363 - val_accuracy: 0.8790 - val_loss: 1.1945
# Restoring model weights from the end of the best epoch: 20.

# %%
# Load the best model
model.load_weights('models/best_Xception_model.keras')

# Evaluate the model
train_loss, train_acc = model.evaluate(train_generator)
val_loss, val_acc = model.evaluate(val_generator)
test_loss, test_acc = model.evaluate(test_generator)

print(f'Train accuracy: {train_acc:.4f}, Validation accuracy: {val_acc:.4f}, Test accuracy: {test_acc:.4f}')
# Out:
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 214s 2s/step - accuracy: 0.8915 - loss: 1.1915
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 61s 2s/step - accuracy: 0.8719 - loss: 1.2074
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 0.8756 - loss: 1.2234
# Train accuracy: 0.8917, Validation accuracy: 0.8719, Test accuracy: 0.8810

# %%
# Plot training & validation accuracy values
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
from tensorflow.keras.models import load_model

# Load the best model (assuming you've saved it during training)
model = load_model('models/best_Xception_model.keras')

# Get predictions
y_pred = model.predict(test_generator)
y_pred_classes = np.argmax(y_pred, axis=1)

# Get true labels
y_true = test_generator.classes

# Get class labels
class_labels = list(test_generator.class_indices.keys())

# Compute confusion matrix
cm = confusion_matrix(y_true, y_pred_classes)

# Normalize the confusion matrix
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# Create a figure and axis
plt.figure(figsize=(20, 18))

# Plot the heatmap
sns.heatmap(cm_normalized, annot=False, cmap='YlOrRd', 
            xticklabels=class_labels, yticklabels=class_labels,
            cbar_kws={'label': 'Normalized Frequency'})

# Customize the plot
plt.title('Confusion Matrix - Xception Model', fontsize=20)
plt.xlabel('Predicted label', fontsize=14)
plt.ylabel('True label', fontsize=14)

# Rotate x-axis labels
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.yticks(fontsize=10)

# Add text annotations for percentages and absolute values
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        plt.text(j+0.5, i+0.5, f"{cm_normalized[i, j]:.1%}\n{cm[i, j]}/{cm[i, :].sum()}", 
                 ha="center", va="center", color="black" if cm_normalized[i, j] < 0.5 else "white", 
                 fontsize=8, fontweight='bold')

plt.tight_layout()
plt.show()
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 49s 3s/step
