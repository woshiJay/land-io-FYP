# %% [markdown]
# HybridV1 (DenseNet with RNN)

# %%
# Libraries
import os
from PIL import Image, ImageEnhance
import cv2
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import DenseNet121
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dropout, Dense, Flatten, GlobalAveragePooling2D, LSTM, BatchNormalization, Reshape
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# Check Image Corruption

# %%
from PIL import UnidentifiedImageError

def check_images(directory):
    corrupted_images = []
    for root, _, files in os.walk(directory):
        for file in files:
            file_path = os.path.join(root, file)
            try:
                img = Image.open(file_path)
                img.verify()  # This will raise an exception if the image is corrupted
            except (UnidentifiedImageError, IOError) as e:
                corrupted_images.append(file_path)
                print(f"Corrupted image: {file_path} - {e}")
    return corrupted_images

corrupted_images = check_images('images')
print(f"Total corrupted images: {len(corrupted_images)}")
# Out:
# Total corrupted images: 0

# %%
# def preprocess_image(image_path, size=(224, 224)):
#     try:
#         img = Image.open(image_path)
        
#         # Quality enhancement
#         enhancer = ImageEnhance.Sharpness(img)
#         img = enhancer.enhance(2.0)  # Increase sharpness
        
#         # Noise reduction
#         image = cv2.cvtColor(np.array(img), cv2.COLOR_RGB2BGR)
#         image = cv2.GaussianBlur(image, (5, 5), 0)
#         img = Image.fromarray(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
        
#         # Consistency
#         img = img.resize(size, Image.LANCZOS)

#         # Normalization
#         img_array = np.array(img) / 255.0
    
#         # Convert back to image
#         img = Image.fromarray((img_array * 255).astype(np.uint8))
        
#         return img
#     except (UnidentifiedImageError, IOError) as e:
#         print(f"Error processing image {image_path}: {e}")
#         return None

# input_dir = 'images_train_test_val/train'
# output_dir = 'processed_images'

# # Apply preprocessing and save to new directory
# for category in os.listdir(input_dir):
#     category_path = os.path.join(input_dir, category)
#     if os.path.isdir(category_path):
#         output_category_path = os.path.join(output_dir, category)
#         if not os.path.exists(output_category_path):
#             os.makedirs(output_category_path)
#         for image_name in os.listdir(category_path):
#             image_path = os.path.join(category_path, image_name)
#             preprocessed_img = preprocess_image(image_path)
#             if preprocessed_img:
#                 preprocessed_img.save(os.path.join(output_category_path, image_name))

# %%
train_dir = 'data/processed_images'
val_dir = 'data/images_train_test_val/validation'
test_dir = 'data/images_train_test_val/test'

datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
)

train_generator = datagen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=64,
    class_mode='categorical'
)

val_generator = datagen.flow_from_directory(
    val_dir,
    target_size=(224, 224),
    batch_size=64,
    class_mode='categorical'
)

test_generator = datagen.flow_from_directory(
    test_dir,
    target_size=(224, 224),
    batch_size=64,
    class_mode='categorical'
)
# Out:
# Found 7350 images belonging to 21 classes.
# Found 2100 images belonging to 21 classes.
# Found 1050 images belonging to 21 classes.

# %%
def create_hybrid_model(optimizer='adam', init_mode='he_uniform', l2_rate=0.01, learning_rate=0.0001):
    base_model = DenseNet121(include_top=False, 
                             weights='imagenet', 
                             input_tensor=Input(shape=(224, 224, 3)))
    
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    
    # Adding LSTM layers
    x = Reshape((1, x.shape[1]))(x)  # Reshape to be compatible with LSTM
    x = LSTM(256, return_sequences=True)(x)
    x = Flatten()(x)
    
    x = Dense(512, activation='relu', kernel_initializer=init_mode, kernel_regularizer=l2(l2_rate))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.6)(x)  # Increased dropout rate
    predictions = Dense(21, activation='softmax', kernel_regularizer=l2(l2_rate))(x)
    
    model = Model(inputs=base_model.input, outputs=predictions)
    
    for layer in base_model.layers[:-30]:  # Fine-tune more layers
        layer.trainable = False
    
    optimizer = Adam(learning_rate=0.0001)
    model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    
    return model

# Compile and train the model as before
model = create_hybrid_model()

# %%
import json
import os

class SaveHistoryCallback(tf.keras.callbacks.Callback):
    def __init__(self, file_path):
        super(SaveHistoryCallback, self).__init__()
        self.file_path = file_path
        # Create the file initially or clear existing file
        if not os.path.exists(file_path):
            with open(file_path, 'w') as f:
                json.dump({}, f)

    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        with open(self.file_path, 'r+') as f:
            history = json.load(f)
            for key, value in logs.items():
                if key in history:
                    history[key].append(value)
                else:
                    history[key] = [value]
            f.seek(0)  # Go to the beginning of the file
            json.dump(history, f, indent=4)

# %%
# Define callbacks
checkpoint = ModelCheckpoint(
    'models/best_HybridV1_model.keras', 
    monitor='val_loss', 
    save_best_only=True, 
    mode='min',
    verbose=1
)

early_stopping = EarlyStopping(
    monitor='val_loss', 
    patience=5, 
    mode='min',
    verbose=1,
    restore_best_weights=True
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss',
    factor=0.5,
    patience=3,
    min_lr=1e-6,
    mode='min',
    verbose=1
)

history = model.fit(
    train_generator,
    epochs=20,
    validation_data=test_generator,
    callbacks=[checkpoint, early_stopping, reduce_lr, SaveHistoryCallback('models/HybridV1_history.json')],
)
# Out:
# Epoch 1/20
# /Users/jay/anaconda3/envs/tf_m1_env/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.2003 - loss: 13.7953
# Epoch 1: val_loss improved from inf to 12.34067, saving model to models/best_HybridV1_model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 544s 4s/step - accuracy: 0.2017 - loss: 13.7861 - val_accuracy: 0.7124 - val_loss: 12.3407 - learning_rate: 1.0000e-04
# Epoch 2/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 6s/step - accuracy: 0.6866 - loss: 10.9409
# Epoch 2: val_loss improved from 12.34067 to 10.75600, saving model to models/best_HybridV1_model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 689s 6s/step - accuracy: 0.6868 - loss: 10.9387 - val_accuracy: 0.8362 - val_loss: 10.7560 - learning_rate: 1.0000e-04
# Epoch 3/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7997 - loss: 9.9176
# Epoch 3: val_loss improved from 10.75600 to 9.42435, saving model to models/best_HybridV1_model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 255s 2s/step - accuracy: 0.7998 - loss: 9.9159 - val_accuracy: 0.8848 - val_loss: 9.4243 - learning_rate: 1.0000e-04
# Epoch 4/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8574 - loss: 9.0722
# Epoch 4: val_loss improved from 9.42435 to 8.48752, saving model to models/best_HybridV1_model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 316s 3s/step - accuracy: 0.8575 - loss: 9.0706 - val_accuracy: 0.9029 - val_loss: 8.4875 - learning_rate: 1.0000e-04
# Epoch 5/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8860 - loss: 8.3079
# Epoch 5: val_loss improved from 8.48752 to 7.73736, saving model to models/best_HybridV1_model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 317s 3s/step - accuracy: 0.8861 - loss: 8.3064 - val_accuracy: 0.9171 - val_loss: 7.7374 - learning_rate: 1.0000e-04
# Epoch 6/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9160 - loss: 7.5842
# Epoch 6: val_loss improved from 7.73736 to 7.07663, saving model to models/best_HybridV1_model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 288s 2s/step - accuracy: 0.9160 - loss: 7.5828 - val_accuracy: 0.9219 - val_loss: 7.0766 - learning_rate: 1.0000e-04
# Epoch 7/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9325 - loss: 6.8962
# Epoch 7: val_loss improved from 7.07663 to 6.43841, saving model to models/best_HybridV1_model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 366s 3s/step - accuracy: 0.9325 - loss: 6.8949 - val_accuracy: 0.9210 - val_loss: 6.4384 - learning_rate: 1.0000e-04
# Epoch 8/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9411 - loss: 6.2722
# Epoch 8: val_loss improved from 6.43841 to 5.83289, saving model to models/best_HybridV1_model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 385s 3s/step - accuracy: 0.9412 - loss: 6.2709 - val_accuracy: 0.9457 - val_loss: 5.8329 - learning_rate: 1.0000e-04
# Epoch 9/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9524 - loss: 5.6686
# Epoch 9: val_loss improved from 5.83289 to 5.25500, saving model to models/best_HybridV1_model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 341s 3s/step - accuracy: 0.9524 - loss: 5.6675 - val_accuracy: 0.9552 - val_loss: 5.2550 - learning_rate: 1.0000e-04
# Epoch 10/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9612 - loss: 5.1182
# Epoch 10: val_loss improved from 5.25500 to 4.77151, saving model to models/best_HybridV1_model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 333s 3s/step - accuracy: 0.9612 - loss: 5.1170 - val_accuracy: 0.9438 - val_loss: 4.7715 - learning_rate: 1.0000e-04
# Epoch 11/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9687 - loss: 4.6034
# Epoch 11: val_loss improved from 4.77151 to 4.29065, saving model to models/best_HybridV1_model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 369s 3s/step - accuracy: 0.9687 - loss: 4.6024 - val_accuracy: 0.9571 - val_loss: 4.2906 - learning_rate: 1.0000e-04
# Epoch 12/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9750 - loss: 4.1250
# Epoch 12: val_loss improved from 4.29065 to 3.83257, saving model to models/best_HybridV1_model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 354s 3s/step - accuracy: 0.9750 - loss: 4.1241 - val_accuracy: 0.9600 - val_loss: 3.8326 - learning_rate: 1.0000e-04
# Epoch 13/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9772 - loss: 3.6990
# Epoch 13: val_loss improved from 3.83257 to 3.42848, saving model to models/best_HybridV1_model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 351s 3s/step - accuracy: 0.9772 - loss: 3.6982 - val_accuracy: 0.9629 - val_loss: 3.4285 - learning_rate: 1.0000e-04
# Epoch 14/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9843 - loss: 3.2929
# Epoch 14: val_loss improved from 3.42848 to 3.07542, saving model to models/best_HybridV1_model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 367s 3s/step - accuracy: 0.9843 - loss: 3.2921 - val_accuracy: 0.9638 - val_loss: 3.0754 - learning_rate: 1.0000e-04
# Epoch 15/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9836 - loss: 2.9350
# Epoch 15: val_loss improved from 3.07542 to 2.73178, saving model to models/best_HybridV1_model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 323s 3s/step - accuracy: 0.9836 - loss: 2.9342 - val_accuracy: 0.9619 - val_loss: 2.7318 - learning_rate: 1.0000e-04
# Epoch 16/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9862 - loss: 2.6011
# Epoch 16: val_loss improved from 2.73178 to 2.42375, saving model to models/best_HybridV1_model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 302s 3s/step - accuracy: 0.9862 - loss: 2.6005 - val_accuracy: 0.9686 - val_loss: 2.4238 - learning_rate: 1.0000e-04
# Epoch 17/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9881 - loss: 2.3043
# Epoch 17: val_loss improved from 2.42375 to 2.16888, saving model to models/best_HybridV1_model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 334s 3s/step - accuracy: 0.9881 - loss: 2.3037 - val_accuracy: 0.9600 - val_loss: 2.1689 - learning_rate: 1.0000e-04
# Epoch 18/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9895 - loss: 2.0352
# Epoch 18: val_loss improved from 2.16888 to 1.92590, saving model to models/best_HybridV1_model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 341s 3s/step - accuracy: 0.9895 - loss: 2.0347 - val_accuracy: 0.9571 - val_loss: 1.9259 - learning_rate: 1.0000e-04
# Epoch 19/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9918 - loss: 1.7898
# Epoch 19: val_loss improved from 1.92590 to 1.68629, saving model to models/best_HybridV1_model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 302s 3s/step - accuracy: 0.9918 - loss: 1.7893 - val_accuracy: 0.9686 - val_loss: 1.6863 - learning_rate: 1.0000e-04
# Epoch 20/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9919 - loss: 1.5702
# Epoch 20: val_loss improved from 1.68629 to 1.47562, saving model to models/best_HybridV1_model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 326s 3s/step - accuracy: 0.9919 - loss: 1.5697 - val_accuracy: 0.9724 - val_loss: 1.4756 - learning_rate: 1.0000e-04
# Restoring model weights from the end of the best epoch: 20.

# %%
# Evaluate the model
model = tf.keras.models.load_model('models/best_HybridV1_model.keras')
train_loss, train_acc = model.evaluate(train_generator)
val_loss, val_acc = model.evaluate(val_generator)
test_loss, test_acc = model.evaluate(test_generator)

print(f'Train accuracy: {train_acc:.4f}, Validation accuracy: {val_acc:.4f}, Test accuracy: {test_acc:.4f}')
# Out:
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 243s 2s/step - accuracy: 0.9992 - loss: 1.4034
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 67s 2s/step - accuracy: 0.9717 - loss: 1.4759
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.9717 - loss: 1.4776
# Train accuracy: 0.9985, Validation accuracy: 0.9714, Test accuracy: 0.9724

# %%
# Plot training & validation accuracy values
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
from tensorflow.keras.models import load_model

# Load the best model (assuming you've saved it during training)
model = load_model('models/best_HybridV1_model.keras')

# Get predictions
y_pred = model.predict(test_generator)
y_pred_classes = np.argmax(y_pred, axis=1)

# Get true labels
y_true = test_generator.classes

# Get class labels
class_labels = list(test_generator.class_indices.keys())

# Compute confusion matrix
cm = confusion_matrix(y_true, y_pred_classes)

# Normalize the confusion matrix
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# Create a figure and axis
plt.figure(figsize=(20, 18))

# Plot the heatmap
sns.heatmap(cm_normalized, annot=False, cmap='YlOrRd', 
            xticklabels=class_labels, yticklabels=class_labels,
            cbar_kws={'label': 'Normalized Frequency'})

# Customize the plot
plt.title('Confusion Matrix - HybridV1 Model', fontsize=20)
plt.xlabel('Predicted label', fontsize=14)
plt.ylabel('True label', fontsize=14)

# Rotate x-axis labels
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.yticks(fontsize=10)

# Add text annotations for percentages and absolute values
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        plt.text(j+0.5, i+0.5, f"{cm_normalized[i, j]:.1%}\n{cm[i, j]}/{cm[i, :].sum()}", 
                 ha="center", va="center", color="black" if cm_normalized[i, j] < 0.5 else "white", 
                 fontsize=8, fontweight='bold')

plt.show()
# Out:
# /Users/jay/anaconda3/envs/tf_m1_env/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 2024-07-24 23:40:57.385882: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 37s 2s/step
