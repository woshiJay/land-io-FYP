# %% [markdown]
# Xception

# %%
# Libraries
import os
from PIL import Image, ImageEnhance
import cv2
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import Xception
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, GlobalAveragePooling2D, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

# %%
def preprocess_image(image_path, size=(224, 224)):
    img = Image.open(image_path)
    
    # Quality enhancement
    enhancer = ImageEnhance.Sharpness(img)
    img = enhancer.enhance(2.0)  # Increase sharpness
    
    # Noise reduction
    image = cv2.cvtColor(np.array(img), cv2.COLOR_RGB2BGR)
    image = cv2.GaussianBlur(image, (5, 5), 0)
    img = Image.fromarray(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    
    # Consistency
    img = img.resize(size, Image.LANCZOS)
    
    # Normalization
    img_array = np.array(img) / 255.0
    
    # Convert back to image
    img = Image.fromarray((img_array * 255).astype(np.uint8))
    
    return img

# Apply preprocessing and save to new directory
input_dir = 'data/images_train_test_val/train'
output_dir = 'data/processed_images'

if not os.path.exists(output_dir):
    os.makedirs(output_dir)

for category in os.listdir(input_dir):
    category_path = os.path.join(input_dir, category)
    if os.path.isdir(category_path):
        output_category_path = os.path.join(output_dir, category)
        if not os.path.exists(output_category_path):
            os.makedirs(output_category_path)
        for image_name in os.listdir(category_path):
            image_path = os.path.join(category_path, image_name)
            preprocessed_img = preprocess_image(image_path)
            preprocessed_img.save(os.path.join(output_category_path, image_name))

# %% [markdown]
# Check for Image Corruption

# %%
from PIL import UnidentifiedImageError

def check_images(directory):
    corrupted_images = []
    for root, _, files in os.walk(directory):
        for file in files:
            file_path = os.path.join(root, file)
            try:
                img = Image.open(file_path)
                img.verify()  # This will raise an exception if the image is corrupted
            except (UnidentifiedImageError, IOError) as e:
                corrupted_images.append(file_path)
                print(f"Corrupted image: {file_path} - {e}")
    return corrupted_images

corrupted_images = check_images('images')
print(f"Total corrupted images: {len(corrupted_images)}")
# Out:
# Total corrupted images: 0

# %%
train_dir = 'data/processed_images'
val_dir = 'data/images_train_test_val/validation'
test_dir = 'data/images_train_test_val/test'

datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
)

train_generator = datagen.flow_from_directory(
    train_dir,
    target_size=(224, 224),
    batch_size=64,
    class_mode='categorical'
)

val_generator = datagen.flow_from_directory(
    val_dir,
    target_size=(224, 224),
    batch_size=64,
    class_mode='categorical'
)

test_generator = datagen.flow_from_directory(
    test_dir,
    target_size=(224, 224),
    batch_size=64,
    class_mode='categorical'
)
# Out:
# Found 7350 images belonging to 21 classes.
# Found 2100 images belonging to 21 classes.
# Found 1050 images belonging to 21 classes.

# %%
def create_xception_model(input_shape=(224, 224, 3), num_classes=21, l2_rate=0.01):
    # Create the base pre-trained model
    base_model = Xception(weights='imagenet', include_top=False, input_shape=input_shape)
    
    # Add custom layers
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(512, activation='relu', kernel_regularizer=l2(0.001))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.6)(x)
    x = Dense(256, activation='relu', kernel_regularizer=l2(0.001))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.6)(x)
    predictions = Dense(21, activation='softmax')(x)

    # Construct the full model
    model = Model(inputs=base_model.input, outputs=predictions)

    # Freeze the base model layers
    for layer in base_model.layers:
        layer.trainable = False

    # Compile the model
    model.compile(optimizer=Adam(learning_rate=0.0001),
                  loss='categorical_crossentropy',
                  metrics=['accuracy'])

    return model

# Create the Xception model
model = create_xception_model()

# %%
import json
import os

class SaveHistoryCallback(tf.keras.callbacks.Callback):
    def __init__(self, file_path):
        super(SaveHistoryCallback, self).__init__()
        self.file_path = file_path
        # Create the file initially or clear existing file
        if not os.path.exists(file_path):
            with open(file_path, 'w') as f:
                json.dump({}, f)

    def on_epoch_end(self, epoch, logs=None):
        logs = logs or {}
        with open(self.file_path, 'r+') as f:
            history = json.load(f)
            for key, value in logs.items():
                if key in history:
                    history[key].append(value)
                else:
                    history[key] = [value]
            f.seek(0)  # Go to the beginning of the file
            json.dump(history, f, indent=4)

# %%
# Define callbacks
checkpoint = ModelCheckpoint(
    'models/best_Xception_model.keras', 
    monitor='val_loss', 
    save_best_only=True, 
    mode='min',
    verbose=1
    )

early_stopping = EarlyStopping(
    monitor='val_loss', 
    patience=5, 
    mode='min',
    verbose=1,
    restore_best_weights=True
    )

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss', 
    factor=0.2, 
    patience=5, 
    min_lr=1e-6
    )


model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

history = model.fit(
    train_generator,
    epochs=20,
    validation_data=val_generator,
    callbacks=[checkpoint, early_stopping, reduce_lr, SaveHistoryCallback('models/xception_history.json')]
)
# Out:
# Epoch 1/20
# /Users/jay/anaconda3/envs/tf_m1_env/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.0958 - loss: 5.4453
# Epoch 1: val_loss improved from inf to 3.59251, saving model to models/best_Xception_model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 478s 4s/step - accuracy: 0.0964 - loss: 5.4402 - val_accuracy: 0.3586 - val_loss: 3.5925 - learning_rate: 1.0000e-04
# Epoch 2/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.3232 - loss: 3.6253
# Epoch 2: val_loss improved from 3.59251 to 2.71011, saving model to models/best_Xception_model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 459s 4s/step - accuracy: 0.3235 - loss: 3.6235 - val_accuracy: 0.6281 - val_loss: 2.7101 - learning_rate: 1.0000e-04
# Epoch 3/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.4593 - loss: 3.0398
# Epoch 3: val_loss improved from 2.71011 to 2.14236, saving model to models/best_Xception_model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 485s 4s/step - accuracy: 0.4595 - loss: 3.0387 - val_accuracy: 0.7324 - val_loss: 2.1424 - learning_rate: 1.0000e-04
# Epoch 4/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.5447 - loss: 2.6540
# Epoch 4: val_loss improved from 2.14236 to 1.89021, saving model to models/best_Xception_model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 453s 4s/step - accuracy: 0.5448 - loss: 2.6535 - val_accuracy: 0.7819 - val_loss: 1.8902 - learning_rate: 1.0000e-04
# Epoch 5/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6128 - loss: 2.4248
# Epoch 5: val_loss improved from 1.89021 to 1.79592, saving model to models/best_Xception_model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 450s 4s/step - accuracy: 0.6128 - loss: 2.4248 - val_accuracy: 0.7981 - val_loss: 1.7959 - learning_rate: 1.0000e-04
# Epoch 6/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6410 - loss: 2.3056
# Epoch 6: val_loss improved from 1.79592 to 1.73199, saving model to models/best_Xception_model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 266s 2s/step - accuracy: 0.6410 - loss: 2.3054 - val_accuracy: 0.8129 - val_loss: 1.7320 - learning_rate: 1.0000e-04
# Epoch 7/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6898 - loss: 2.1582
# Epoch 7: val_loss improved from 1.73199 to 1.66274, saving model to models/best_Xception_model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 300s 3s/step - accuracy: 0.6897 - loss: 2.1583 - val_accuracy: 0.8348 - val_loss: 1.6627 - learning_rate: 1.0000e-04
# Epoch 8/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7132 - loss: 2.0687
# Epoch 8: val_loss improved from 1.66274 to 1.63350, saving model to models/best_Xception_model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 462s 4s/step - accuracy: 0.7132 - loss: 2.0688 - val_accuracy: 0.8319 - val_loss: 1.6335 - learning_rate: 1.0000e-04
# Epoch 9/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.7150 - loss: 2.0196
# Epoch 9: val_loss improved from 1.63350 to 1.58468, saving model to models/best_Xception_model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 527s 5s/step - accuracy: 0.7151 - loss: 2.0194 - val_accuracy: 0.8524 - val_loss: 1.5847 - learning_rate: 1.0000e-04
# Epoch 10/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7346 - loss: 1.9728
# Epoch 10: val_loss improved from 1.58468 to 1.55300, saving model to models/best_Xception_model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 363s 3s/step - accuracy: 0.7347 - loss: 1.9725 - val_accuracy: 0.8605 - val_loss: 1.5530 - learning_rate: 1.0000e-04
# Epoch 11/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7414 - loss: 1.9061
# Epoch 11: val_loss improved from 1.55300 to 1.55165, saving model to models/best_Xception_model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 351s 3s/step - accuracy: 0.7415 - loss: 1.9059 - val_accuracy: 0.8471 - val_loss: 1.5517 - learning_rate: 1.0000e-04
# Epoch 12/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7619 - loss: 1.8533
# Epoch 12: val_loss improved from 1.55165 to 1.52106, saving model to models/best_Xception_model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 344s 3s/step - accuracy: 0.7618 - loss: 1.8534 - val_accuracy: 0.8586 - val_loss: 1.5211 - learning_rate: 1.0000e-04
# Epoch 13/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7717 - loss: 1.8177
# Epoch 13: val_loss improved from 1.52106 to 1.46640, saving model to models/best_Xception_model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 344s 3s/step - accuracy: 0.7717 - loss: 1.8177 - val_accuracy: 0.8805 - val_loss: 1.4664 - learning_rate: 1.0000e-04
# Epoch 14/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7855 - loss: 1.7601
# Epoch 14: val_loss improved from 1.46640 to 1.45022, saving model to models/best_Xception_model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1593s 14s/step - accuracy: 0.7855 - loss: 1.7601 - val_accuracy: 0.8800 - val_loss: 1.4502 - learning_rate: 1.0000e-04
# Epoch 15/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7859 - loss: 1.7446
# Epoch 15: val_loss improved from 1.45022 to 1.43821, saving model to models/best_Xception_model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 424s 4s/step - accuracy: 0.7860 - loss: 1.7446 - val_accuracy: 0.8781 - val_loss: 1.4382 - learning_rate: 1.0000e-04
# Epoch 16/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8022 - loss: 1.6958
# Epoch 16: val_loss improved from 1.43821 to 1.42569, saving model to models/best_Xception_model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 425s 4s/step - accuracy: 0.8022 - loss: 1.6957 - val_accuracy: 0.8824 - val_loss: 1.4257 - learning_rate: 1.0000e-04
# Epoch 17/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8147 - loss: 1.6698
# Epoch 17: val_loss improved from 1.42569 to 1.38518, saving model to models/best_Xception_model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 424s 4s/step - accuracy: 0.8147 - loss: 1.6698 - val_accuracy: 0.8914 - val_loss: 1.3852 - learning_rate: 1.0000e-04
# Epoch 18/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8175 - loss: 1.6281
# Epoch 18: val_loss did not improve from 1.38518
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 420s 4s/step - accuracy: 0.8175 - loss: 1.6281 - val_accuracy: 0.8871 - val_loss: 1.4030 - learning_rate: 1.0000e-04
# Epoch 19/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8160 - loss: 1.5939
# Epoch 19: val_loss improved from 1.38518 to 1.38076, saving model to models/best_Xception_model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 423s 4s/step - accuracy: 0.8161 - loss: 1.5938 - val_accuracy: 0.8952 - val_loss: 1.3808 - learning_rate: 1.0000e-04
# Epoch 20/20
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8213 - loss: 1.5929
# Epoch 20: val_loss improved from 1.38076 to 1.35165, saving model to models/best_Xception_model.keras
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 429s 4s/step - accuracy: 0.8213 - loss: 1.5928 - val_accuracy: 0.8929 - val_loss: 1.3516 - learning_rate: 1.0000e-04
# Restoring model weights from the end of the best epoch: 20.

# %%
# Load the best model
model.load_weights('models/best_Xception_model.keras')

# Evaluate the model
train_loss, train_acc = model.evaluate(train_generator)
val_loss, val_acc = model.evaluate(val_generator)
test_loss, test_acc = model.evaluate(test_generator)

print(f'Train accuracy: {train_acc:.4f}, Validation accuracy: {val_acc:.4f}, Test accuracy: {test_acc:.4f}')
# Out:
#  33/115 ━━━━━━━━━━━━━━━━━━━━ 4:43 3s/step - accuracy: 0.8960 - loss: 1.3388

# %%
# Plot training & validation accuracy values
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
from tensorflow.keras.models import load_model

# Load the best model (assuming you've saved it during training)
model = load_model('models/best_Xception_model.keras')

# Get predictions
y_pred = model.predict(test_generator)
y_pred_classes = np.argmax(y_pred, axis=1)

# Get true labels
y_true = test_generator.classes

# Get class labels
class_labels = list(test_generator.class_indices.keys())

# Compute confusion matrix
cm = confusion_matrix(y_true, y_pred_classes)

# Normalize the confusion matrix
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

# Create a figure and axis
plt.figure(figsize=(20, 18))

# Plot the heatmap
sns.heatmap(cm_normalized, annot=False, cmap='YlOrRd', 
            xticklabels=class_labels, yticklabels=class_labels,
            cbar_kws={'label': 'Normalized Frequency'})

# Customize the plot
plt.title('Confusion Matrix - Xception Model', fontsize=20)
plt.xlabel('Predicted label', fontsize=14)
plt.ylabel('True label', fontsize=14)

# Rotate x-axis labels
plt.xticks(rotation=45, ha='right', fontsize=10)
plt.yticks(fontsize=10)

# Add text annotations for percentages and absolute values
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        plt.text(j+0.5, i+0.5, f"{cm_normalized[i, j]:.1%}\n{cm[i, j]}/{cm[i, :].sum()}", 
                 ha="center", va="center", color="black" if cm_normalized[i, j] < 0.5 else "white", 
                 fontsize=8, fontweight='bold')

plt.tight_layout()
plt.show()
# Out:
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 43s 2s/step
